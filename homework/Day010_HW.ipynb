# %% [markdown]
# ### 專案名稱: 網路爬蟲實戰研習馬拉松
# ### 功能描述: 第10天作業
# ### 版權所有: Dunk
# ### 程式撰寫: Dunk
# ### 撰寫日期：2020/06/17
# ### 改版日期:
# ### 改版備註:

# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ### ANS:

# %% [markdown]
# requests + beatifulsoup
# >- 要指定post or get
# >- 會將內容不會url encode(中文字還是顯示中文)
#
# grab + pyquery
# >- 不用指定post or get
# >- 會將內容自動使用url encode(中文字顯示成網頁編碼格式)

# %%
# 設定網址
url = 'https://www.bot.com.tw/Pages/default.aspx'

# %% [markdown]
# ## requests + BeautifulSoup

# %%
import requests
res = requests.get(url)
res.text
# Out:
# '\r\n<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\r\n<html __expr-val-dir="ltr" lang="zh-tw" dir="ltr">\r\n<head><meta name="GENERATOR" content="Moss" /><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta http-equiv="Expires" content="0" />\n<title>臺灣銀行</title>\n<meta name="DC.Title" content="臺灣銀行網站" /> \n<meta name="DC.Creator" content="臺灣銀行" /> \n<meta name="DC.Subject" content="臺灣銀行網站首頁" /> \n<meta name="DC.Description" content="臺灣銀行網站" /> \n<meta name="DC.Contributor" content="臺灣銀行" /> \n<meta name="DC.Language" content="中文" /> \n<meta name="DC.Type" content="text/html" /> \n<meta name="DC.Format" content="text" /> \n<meta name="DC.Source" content="臺灣銀行" /> \n<meta name="DC.Coverage" content="2002/8/29 上午 12:00:00" /> \n<meta name="DC.Publisher" content="臺灣銀行" /> \n<meta name="DC.Date" content="2002/8/29 上午 12:00:00" /> \n<meta name="DC.Identifier" content="307200000N" /> \n<meta name="DC.Relation" content="臺灣銀行" /> \n<meta name="DC.Rights" content="臺灣銀行" /> \n<meta name="Category.Theme" content="540" /> \n<meta name="Category.Cake" content="472" /> \n<meta name="Category.Service" content="I61" /> \n<meta name="Keywords" content="臺灣銀行,網路銀行,網路ATM,基金理財, 證券下單,學雜費網站,就學貸款" /> \n\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta name="viewport" content="width=device-width, initial-scale=1" /><META NAME="ROBOTS" CONTENT="NOHTMLINDEX"/>\r\n\t<!--Styles used for positioning, font and spacing definitions-->\r\n\t<script src="/_layouts/1028/init.js?rev=%2FvGLnMNy9ZPSCcX%2Bcf70Hw%3D%3D"></script>\n<script type="text/javascript" language="javascript" src="/_layouts/1028/core.js?rev=uKaHlf1Swo541jQuYoQMdA%3D%3D" defer></script>\n<script type="text/javascript" language="javascript" src="/_layouts/1028/non_ie.js?rev=yfNry4hY0Gwa%2FPDNGrqXVg%3D%3D"></script>\n\r\n\t<!--Placeholder for additional overrides-->\r\n\t<link href="/Documents/Default_Style/core_new.css" rel="stylesheet" type="text/css" /><link href="/img/images3/mossimages/style.css" rel="stylesheet" type="text/css" /><link href="/img/css/menucss_ch.css" rel="stylesheet" type="text/css" />\r\n    <script src="/_layouts/js/menujs.js" type="text/javascript"></script>\r\n\r\n<style type="text/css">\r\n.leftNav\r\n{\r\n    display:none;\r\n\tmargin-right:15px; \r\n\tmargin-left:7px; \r\n\tmargin-top:4px;\r\n\tpadding-top:0px;\r\n\tborder:1px #8997BC solid;\r\n\tbackground-color: #D0D6E3;\r\n\twidth:160px;\r\n}\r\n.leftNavSpacer\r\n{\r\n\tdisplay:none;\r\n\twidth:160px;\r\n}\r\n.leftNavSelected\r\n{\r\n\tdisplay:none;\r\n\tbackground-color: #B2BCD3;\r\n\tcolor: #F4F5F9;\r\n\tborder-top:1px #F4F5FF solid;\r\n\tborder-bottom:1px #F4F5FF solid;\r\n\tline-height:14pt;\r\n}\r\n.leftNav3\r\n{\r\n\tdisplay:none;\r\n\tcolor: #354260;\r\n}\r\n.leftNav2\r\n{\r\n\tdisplay:none;\r\n\tcolor: #354260;\r\n}\r\n.leftNav1\r\n{\r\n\tdisplay:none;\r\n\tcolor: #354260;\r\n}\r\n.leftNav1\r\n{\r\n\tdisplay:none;\r\n\tfont-family: ??\uef3c\ue7a0???;  \r\n\tfont-size: 9pt; \r\n\tfont-weight:bold; \r\n\tline-height:14pt;\r\n}\r\n.leftNav1 a\r\n{\r\n\tdisplay:none;\r\n\tfont-family: ??\uef3c\ue7a0???;  \r\n\tfont-size: 9pt; \r\n\tfont-weight:bold; \r\n\tpadding-left:5px; \r\n\tdisplay:block;\r\n\tpadding-right:10px; \r\n}\r\n.leftNav2\r\n{\t\r\n\tdisplay:none;\r\n\tfont-family: ??\uef3c\ue7a0???;  \r\n\tfont-size: 9pt; \r\n\tline-height:14pt;\r\n}\r\n.leftNav2 a\r\n{\r\n\tdisplay:none;\r\n\tpadding-left:10px; \r\n\tdisplay:block;\r\n\tpadding-right:10px; \r\n}\r\n.leftNav3\r\n{\t\r\n\tdisplay:none;\r\n\tfont-family: ??\uef3c\ue7a0???;  \r\n\tfont-size: 9pt; \r\n\tline-height:14pt;\r\n}\r\n.leftNav3 a\r\n{\r\n\tdisplay:none;\r\n\tpadding-left:18px; \r\n\tdisplay:block;\r\n\tpadding-right:10px; \r\n}\r\n.leftNavHover\r\n{\r\n\tdisplay:none;\r\n\tbackground-color: #596E9E;\r\n\tcolor:#FFFFFF;\r\n}\r\n.leftNavFlyOuts\r\n{\r\n\tdisplay:none;\r\n\tfont-family:??\uef3c\ue7a0???; \r\n\tfont-size:9pt; \r\n\tborder-top:1px #CB ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text)
title = soup.find('title')
print(type(title), title)
# Out:
# <class 'bs4.element.Tag'> <title>臺灣銀行</title>

# %% [markdown]
# ## Grab + PyQuery

# %%
from grab import Grab
g = Grab()
resp = g.go(url)
resp.body
# Out:
# b'\r\n<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\r\n<html __expr-val-dir="ltr" lang="zh-tw" dir="ltr">\r\n<head><meta name="GENERATOR" content="Moss" /><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta http-equiv="Expires" content="0" />\n<title>\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c</title>\n<meta name="DC.Title" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c\xe7\xb6\xb2\xe7\xab\x99" /> \n<meta name="DC.Creator" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c" /> \n<meta name="DC.Subject" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c\xe7\xb6\xb2\xe7\xab\x99\xe9\xa6\x96\xe9\xa0\x81" /> \n<meta name="DC.Description" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c\xe7\xb6\xb2\xe7\xab\x99" /> \n<meta name="DC.Contributor" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c" /> \n<meta name="DC.Language" content="\xe4\xb8\xad\xe6\x96\x87" /> \n<meta name="DC.Type" content="text/html" /> \n<meta name="DC.Format" content="text" /> \n<meta name="DC.Source" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c" /> \n<meta name="DC.Coverage" content="2002/8/29 \xe4\xb8\x8a\xe5\x8d\x88 12:00:00" /> \n<meta name="DC.Publisher" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c" /> \n<meta name="DC.Date" content="2002/8/29 \xe4\xb8\x8a\xe5\x8d\x88 12:00:00" /> \n<meta name="DC.Identifier" content="307200000N" /> \n<meta name="DC.Relation" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c" /> \n<meta name="DC.Rights" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c" /> \n<meta name="Category.Theme" content="540" /> \n<meta name="Category.Cake" content="472" /> \n<meta name="Category.Service" content="I61" /> \n<meta name="Keywords" content="\xe8\x87\xba\xe7\x81\xa3\xe9\x8a\x80\xe8\xa1\x8c,\xe7\xb6\xb2\xe8\xb7\xaf\xe9\x8a\x80\xe8\xa1\x8c,\xe7\xb6\xb2\xe8\xb7\xafATM,\xe5\x9f\xba\xe9\x87\x91\xe7\x90\x86\xe8\xb2\xa1, \xe8\xad\x89\xe5\x88\xb8\xe4\xb8\x8b\xe5\x96\xae,\xe5\xad\xb8\xe9\x9b\x9c\xe8\xb2\xbb\xe7\xb6\xb2\xe7\xab\x99,\xe5\xb0\xb1\xe5\xad\xb8\xe8\xb2\xb8\xe6\xac\xbe" /> \n\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta name="viewport" content="width=device-width, initial-scale=1" /><META NAME="ROBOTS" CONTENT="NOHTMLINDEX"/>\r\n\t<!--Styles used for positioning, font and spacing definitions-->\r\n\t<script src="/_layouts/1028/init.js?rev=%2FvGLnMNy9ZPSCcX%2Bcf70Hw%3D%3D"></script>\n<script type="text/javascript" language="javascript" src="/_layouts/1028/core.js?rev=uKaHlf1Swo541jQuYoQMdA%3D%3D" defer></script>\n<script type="text/javascript" language="javascript" src="/_layouts/1028/non_ie.js?rev=yfNry4hY0Gwa%2FPDNGrqXVg%3D%3D"></script>\n\r\n\t<!--Placeholder for additional overrides-->\r\n\t<link href="/Documents/Default_Style/core_new.css" rel="stylesheet" type="text/css" /><link href="/img/images3/mossimages/style.css" rel="stylesheet" type="text/css" /><link href="/img/css/menucss_ch.css" rel="stylesheet" type="text/css" />\r\n    <script src="/_layouts/js/menujs.js" type="text/javascript"></script>\r\n\r\n<style type="text/css">\r\n.leftNav\r\n{\r\n    display:none;\r\n\tmargin-right:15px; \r\n\tmargin-left:7px; \r\n\tmargin-top:4px;\r\n\tpadding-top:0px;\r\n\tborder:1px #8997BC solid;\r\n\tbackground-color: #D0D6E3;\r\n\twidth:160px;\r\n}\r\n.leftNavSpacer\r\n{\r\n\tdisplay:none;\r\n\twidth:160px;\r\n}\r\n.leftNavSelected\r\n{\r\n\tdisplay:none;\r\n\tbackground-color: #B2BCD3;\r\n\tcolor: #F4F5F9;\r\n\tborder-top:1px #F4F5FF solid;\r\n\tborder-bottom:1px #F4F5FF solid;\r\n\tline-height:14pt;\r\n}\r\n.leftNav3\r\n{\r\n\tdisplay:none;\r\n\tcolor: #354260;\r\n}\r\n.leftNav2\r\n{\r\n\tdisplay:none;\r\n\tcolor: #354260;\r\n}\r\n.leftNav1\r\n{\r\n\tdisplay:none;\r\n\tcolor: #354260;\r\n}\r\n.leftNav1\r\n{\r\n\tdisplay:none;\r\n\tfont-family: ??\xee\xbc\xbc\xee\x9e\xa0???;  \r\n\tfont-size: 9pt; \r\n\tfont-weight:bold; \r\n\tline-height:14pt;\r\n}\r\n ...

# %%
from pyquery import PyQuery as pq
doc = pq(resp.body)
title = doc('title')
print(type(title), title.text())
# Out:
# <class 'pyquery.pyquery.PyQuery'> 臺灣銀行
